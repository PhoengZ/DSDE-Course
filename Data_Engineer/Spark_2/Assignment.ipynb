# %% [markdown]
# # Spark Preparation
# We check if we are in Google Colab.  If this is the case, install all necessary packages.
#
# To run spark in Colab, we need to first install all the dependencies in Colab environment i.e. Apache Spark 3.3.2 with hadoop 3.3, Java 8 and Findspark to locate the spark in the system. The tools installation can be carried out inside the Jupyter Notebook of the Colab.
# Learn more from [A Must-Read Guide on How to Work with PySpark on Google Colab for Data Scientists!](https://www.analyticsvidhya.com/blog/2020/11/a-must-read-guide-on-how-to-work-with-pyspark-on-google-colab-for-data-scientists/)

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %%
if IN_COLAB:
    # !apt-get install openjdk-8-jdk-headless -qq > /dev/null
    # !wget -q https://dlcdn.apache.org/spark/spark-3.3.2/spark-3.3.2-bin-hadoop3.tgz
    # !tar xf spark-3.3.2-bin-hadoop3.tgz
    # !mv spark-3.3.2-bin-hadoop3 spark
    # !pip install -q findspark
    import os
    os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
    os.environ["SPARK_HOME"] = "/content/spark"

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import max, avg

# %% [markdown]
# # Start a Local Cluster

# %%
spark = SparkSession.builder.master('local').appName("App1").getOrCreate()

# %% [markdown]
# # Spark Assignment
#
# Based on the movie review dataset in 'netflix-rotten-tomatoes-metacritic-imdb.csv', answer the below questions.
#
# **Note:** do not clean or remove missing data

# %%
df = spark.read.csv("netflix-rotten-tomatoes-metacritic-imdb.csv", header=True, inferSchema=True)
df.printSchema()
# Out:
# root
#  |-- Title: string (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- Languages: string (nullable = true)
#  |-- Series or Movie: string (nullable = true)
#  |-- Hidden Gem Score: double (nullable = true)
#  |-- Country Availability: string (nullable = true)
#  |-- Runtime: string (nullable = true)
#  |-- Director: string (nullable = true)
#  |-- Writer: string (nullable = true)
#  |-- Actors: string (nullable = true)
#  |-- View Rating: string (nullable = true)
#  |-- IMDb Score: string (nullable = true)
#  |-- Rotten Tomatoes Score: string (nullable = true)
#  |-- Metacritic Score: string (nullable = true)
#  |-- Awards Received: double (nullable = true)
#  |-- Awards Nominated For: double (nullable = true)
#  |-- Boxoffice: string (nullable = true)
#  |-- Release Date: string (nullable = true)
#  |-- Netflix Release Date: string (nullable = true)
#  |-- Production House: string (nullable = true)
# ...

# %%
cols = [col.replace(" ", "_") for col in df.columns]
df = df.toDF(*cols)
df.printSchema()
# Out:
# root
#  |-- Title: string (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- Languages: string (nullable = true)
#  |-- Series_or_Movie: string (nullable = true)
#  |-- Hidden_Gem_Score: double (nullable = true)
#  |-- Country_Availability: string (nullable = true)
#  |-- Runtime: string (nullable = true)
#  |-- Director: string (nullable = true)
#  |-- Writer: string (nullable = true)
#  |-- Actors: string (nullable = true)
#  |-- View_Rating: string (nullable = true)
#  |-- IMDb_Score: string (nullable = true)
#  |-- Rotten_Tomatoes_Score: string (nullable = true)
#  |-- Metacritic_Score: string (nullable = true)
#  |-- Awards_Received: double (nullable = true)
#  |-- Awards_Nominated_For: double (nullable = true)
#  |-- Boxoffice: string (nullable = true)
#  |-- Release_Date: string (nullable = true)
#  |-- Netflix_Release_Date: string (nullable = true)
#  |-- Production_House: string (nullable = true)
# ...

# %% [markdown]
# ## What is the maximum and average of the overall hidden gem score?

# %%
results = df.select(max(df["Hidden_Gem_Score"]),avg(df["Hidden_Gem_Score"])).collect()
print(round(results[0][0],2), round(results[0][1],2))
# Out:
# 9.8 5.94

# %% [markdown]
# ## How many movies that are available in Korea?

# %%
# 1
print(df.filter(df["Languages"].contains("Korea")).select("Title").distinct().count())
# 2
print(df.filter(df["Languages"].contains("Korea")).select("Title").count())
# Out:
# 724
# 735

# %%
# 3
print(df.filter(df["Country_Availability"].contains("Korea")).select("Title").distinct().count())
# 4
print(df.filter(df["Country_Availability"].contains("Korea")).select("Title").count())
# Out:
# 4789
# 4845

# %% [markdown]
# ## Which director has the highest average hidden gem score?

# %%
df_avg = df.groupby("Director").agg({"Hidden_Gem_Score":"avg"})
max_score = df_avg.select(max("avg(Hidden_Gem_Score)")).collect()[0][0]
df_avg.filter(df_avg["avg(Hidden_Gem_Score)"] == max_score).select("Director").show()
# Out:
# +-----------+
# |   Director|
# +-----------+
# |Dorin Marcu|
# +-----------+

# %%
# Easier 
df.groupBy("Director").agg({"Hidden_Gem_Score":"avg"}).orderBy("avg(Hidden_Gem_Score)", ascending=False).select("Director").show(1)
# Out:
# +-----------+
# |   Director|
# +-----------+
# |Dorin Marcu|
# +-----------+
# only showing top 1 row

# %% [markdown]
# ## How many genres are there in the dataset?

# %%
print(df.filter(df["Genre"].isNull()).count())
print(df.filter(df["Genre"].isNotNull()).count())
# Out:
# 1710
# 13770

# %%
df.filter(df["Genre"].isNotNull()).select("Genre").show(20)
# Out:
# +--------------------+
# |               Genre|
# +--------------------+
# |Crime, Drama, Fan...|
# |              Comedy|
# |     Drama, Thriller|
# |               Drama|
# |Animation, Short,...|
# |     Comedy, Romance|
# |               Drama|
# |               Crime|
# |               Drama|
# |              Comedy|
# |Comedy, Family, F...|
# |Crime, Drama, Fan...|
# |               Drama|
# |       Comedy, Drama|
# |        Short, Drama|
# |Crime, Drama, Thr...|
# |Action, Adventure...|
# |Adventure, Drama,...|
# |               Music|
# |     Drama, Thriller|
# +--------------------+
# only showing top 20 rows

# %%
genres = df.filter(df["Genre"].isNotNull()).select("Genre").collect()
s = set()
for genre in genres:
    g = genre[0].split(", ")
    for e in g:
        s.add(e)
print(len(s))
# Out:
# 28

# %%
spark.stop()
